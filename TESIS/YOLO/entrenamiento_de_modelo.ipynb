# %%
# %cd "/home/victor-cimat/tesis/YOLO/yolov5"
import torch
import utils
display = utils.notebook_init()  # checks
# %cd "/home/victor-cimat/tesis/YOLO"
# Out:
# YOLOv5 🚀 v6.2-183-gc98128f Python-3.8.10 torch-1.12.1+cu102 CUDA:0 (Quadro RTX 5000 with Max-Q Design, 16125MiB)
# Setup complete ✅ (12 CPUs, 125.4 GB RAM, 97.0/937.3 GB disk)
# /home/victor-cimat/tesis/YOLO

# %%
print('torch %s %s' % (torch.__version__, 
                       torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.12.1+cu102 _CudaDeviceProperties(name='Quadro RTX 5000 with Max-Q Design', major=7, minor=5, total_memory=16125MB, multi_processor_count=48)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# from roboflow import Roboflow
# %cd "/home/victor-cimat/tesis/YOLO"
# rf = Roboflow(api_key="H2INZriXPwrRnfcGorvA")
# project = rf.workspace("hojasamarillas").project("ext-hojas-amarillas")
# dataset = project.version(5).download("yolov5")

# %%
# Dir a código de entrenamiemto en yolov5
train = "/home/victor-cimat/tesis/YOLO/yolov5/train.py" 
# Dir a datos yaml descargados de Roboflow
data = "/home/victor-cimat/tesis/YOLO/Ext-HOJAS-AMARILLAS-5/data.yaml"
# Carpeta donde guardaremos resultados
output = "/home/victor-cimat/tesis/YOLO/outtrain"
modelo = "/home/victor-cimat/tesis/YOLO/yolov5/models/yolov5x.yaml"

# %%
logger = 'TensorBoard' #@param ['TensorBoard', 'Comet', 'ClearML', 'W&B']

if logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir /home/victor-cimat/tesis/YOLO/outtrain
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 20988), started 0:00:44 ago. (Use '!kill 20988' to kill it.)
#       <iframe id="tensorboard-frame-a80609aa5cb51bda" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a80609aa5cb51bda");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !python3 $train --img 640 --batch 16 --epochs 600 --data $data --cfg $modelo --weights ''  --name $output --cache ram
# Out:
# train: weights=, cfg=/home/victor-cimat/tesis/YOLO/yolov5/models/yolov5x.yaml, data=/home/victor-cimat/tesis/YOLO/Ext-HOJAS-AMARILLAS-5/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=600, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=/home/victor-cimat/tesis/YOLO/outtrain, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-183-gc98128f Python-3.8.10 torch-1.12.1+cu102 CUDA:0 (Quadro RTX 5000 with Max-Q Design, 16125MiB)
#
# ...

# %%
direc = "/home/victor-cimat/tesis/YOLO/outtrain/"

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rend = pd.read_csv(direc+"results.csv")

# %%
rend
# Out:
#                     epoch        train/box_loss        train/obj_loss  \
# 0                       0              0.113230              0.050851
# 1                       1              0.110210              0.051762
# 2                       2              0.102520              0.056992
# 3                       3              0.085557              0.064024
# 4                       4              0.073687              0.067806
# ..                    ...                   ...                   ...
# 401                   401              0.011874              0.013006
# 402                   402              0.012042              0.012606
# 403                   403              0.012103              0.013182
# 404                   404              0.012374              0.013300
# 405                   405              0.011759              0.012639
#
#            train/cls_loss     metrics/precision  ...          val/obj_loss  \
# ...

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

# %%
fig, ax = plt.subplots(figsize=(6,5), dpi=80)

box = 6
plt.plot(rend['               epoch'],
         smooth(rend['      train/box_loss'],box),
         'green',
         label='Entrenamiento')
plt.plot(rend['               epoch'],
         smooth(rend['        val/box_loss'],box),
         'red',
         label='Validación')
plt.title('')
plt.xlabel('Epocas', fontsize=20)
plt.ylabel('Box Loss', fontsize=20)
plt.grid()
plt.legend()
plt.savefig(direc+'Box_Loss.png')

# %%
fig, ax = plt.subplots(figsize=(6,5), dpi=80)

box = 6
plt.plot(rend['               epoch'],
         smooth(rend['      train/obj_loss'],box),
         'green',
         label='Entrenamiento')
plt.plot(rend['               epoch'],
         smooth(rend['        val/obj_loss'],box),
         'red',
         label='Validación')
plt.title('')
plt.xlabel('Epocas', fontsize=20)
plt.ylabel('Object Loss', fontsize=20)
plt.grid()
plt.legend()
plt.savefig(direc+'Obj_Loss.png')

# %%
fig, ax = plt.subplots(figsize=(6,5), dpi=80)

box = 6
plt.plot(rend['               epoch'],
         smooth(rend['      train/cls_loss'],box),
         'green',
         label='Entrenamiento')
plt.plot(rend['               epoch'],
         smooth(rend['        val/cls_loss'],box),
         'red',
         label='Validación')
plt.title('')
plt.xlabel('Epocas', fontsize=20)
plt.ylabel('Cls Loss', fontsize=20)
plt.ylim(-0.001,0.05)
plt.grid()
plt.legend()
plt.savefig(direc+'Cls_Loss.png')

# %%
fig, ax = plt.subplots(figsize=(6,5), dpi=80)

box = 16
plt.plot(rend['               epoch'],
         smooth(rend['   metrics/precision'],box),
         'k')
plt.plot(rend['               epoch'],
         rend['   metrics/precision'],
         'k',alpha=0.2)
plt.title('')
plt.xlabel('Epocas', fontsize=20)
plt.ylabel('Precisión', fontsize=20)
plt.grid()
plt.savefig(direc+'Precision.png')

# %%
fig, ax = plt.subplots(figsize=(6,5), dpi=80)

box = 16
plt.plot(rend['               epoch'],
         smooth(rend['      metrics/recall'],box),
         'k')
plt.plot(rend['               epoch'],
         rend['      metrics/recall'],
         'k',alpha=0.2)
plt.title('')
plt.xlabel('Epocas', fontsize=20)
plt.ylabel('Recall', fontsize=20)
plt.grid()
plt.savefig(direc+'recall.png')

# %%
fig, ax = plt.subplots(figsize=(6,5), dpi=80)

box = 16
plt.plot(rend['               epoch'],
         smooth(rend['     metrics/mAP_0.5'],box),
         'k')
plt.plot(rend['               epoch'],
         rend['     metrics/mAP_0.5'],
         'k',alpha=0.2)
plt.title('')
plt.xlabel('Epocas', fontsize=20)
plt.ylabel('mAP 0.5', fontsize=20)
plt.grid()
plt.savefig(direc+'mAP05.png')

# %%
fig, ax = plt.subplots(figsize=(6,5), dpi=80)

box = 16
plt.plot(rend['               epoch'],
         smooth(rend['metrics/mAP_0.5:0.95'],box),
         'k')
plt.plot(rend['               epoch'],
         rend['metrics/mAP_0.5:0.95'],
         'k',alpha=0.2)
plt.title('')
plt.xlabel('Epocas', fontsize=20)
plt.ylabel('mAP 0.5:0.95', fontsize=20)
plt.grid()
plt.savefig(direc+'mAP95.png')
